# %%
import os
os.getcwd()

import pandas as pd
from textblob import TextBlob

# %%
df = pd.read_csv('Result_China.csv')
df
# Out:
#    Duration                         Speaker  \
# 0     11:35               James K. Thornton
# 1      9:17                    Hongqiao Liu
# 2     11:51                          Ma Jun
# 3      5:39                    Robert Chang
# 4     11:23                    Nimisha Jain
# 5     11:44                      Huang Hung
# 6      4:43                     Shunan Teng
# 7     58:23                        Gary Liu
# 8     10:50                       Fang Ruan
# 9     14:27              Jennifer Zhu Scott
# 10     3:33             Sheila Marie Orfano
# 11     4:48             Anne F. Broadbridge
# 12     5:56                      Nanfu Wang
# 13     4:30                     Bill Schutt
# 14     3:47                     Shunan Teng
# 15     3:44                     Shunan Teng
# 16    18:43                  Graham Allison
# 17    12:18                       Angel Hsu
# 18    12:41                        Gary Liu
# 19    13:38                     Angela Wang
# ...

# %%
blob = TextBlob(df['Transcript'][0])

# %%
blob.sentiment
# Out:
# Sentiment(polarity=0.1421050279995234, subjectivity=0.39777691727233006)

# %%
for i in range(len(df['Transcript'])):
    blob = TextBlob(df['Transcript'][i])
#     print("{}: {}".format(df['Title'][i], blob.sentiment))
    print("{}: {}".format(i, blob.sentiment))
# Out:
# 0: Sentiment(polarity=0.1421050279995234, subjectivity=0.39777691727233006)
# 1: Sentiment(polarity=0.0867958152958153, subjectivity=0.3848472386199658)
# 2: Sentiment(polarity=0.0783292999438833, subjectivity=0.3708494668911338)
# 3: Sentiment(polarity=0.0873319003527337, subjectivity=0.3149415784832452)
# 4: Sentiment(polarity=0.23732361457527018, subjectivity=0.48479583146801686)
# 5: Sentiment(polarity=0.05858979635388085, subjectivity=0.3956740696705487)
# 6: Sentiment(polarity=0.08463203463203466, subjectivity=0.4886840149899849)
# 7: Sentiment(polarity=0.1287094461094461, subjectivity=0.46342965922965845)
# 8: Sentiment(polarity=0.20213890980195334, subjectivity=0.4684187109187108)
# 9: Sentiment(polarity=0.14567003807936454, subjectivity=0.44521877661774034)
# 10: Sentiment(polarity=0.17611068518045261, subjectivity=0.44331175284663665)
# 11: Sentiment(polarity=0.15374988486690616, subjectivity=0.39102882932670174)
# ...
